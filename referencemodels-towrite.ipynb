# %% [markdown]
# * Sklearn Regression Model - Done with California Housing Price Dataset
#
# * Sklearn MultiClass Classification Model - Done with MNIST Dataset
#
# * Sklearn Binary Classification Model
#
# * Sklearn PCA
#
# * TF binary classification model
#
# * TF multi class classfication model - Done with Fashion MNIST Dataset
#
# * TF regression model
#
# * CNN for CV
#
# * processing sequence using RNN and CNN
#
# * NLP with RNN and Attention
#
# * Autoencoders, GANs and Diffusion Models
#
# * Reinforcement Learning
